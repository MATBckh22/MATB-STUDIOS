# %%
HW = "Hello World"
for i in range(0,5,1): print(HW)
x = 1
if x == 1: print ("x is", x)
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# x is 1

# %%
myint = 7
print(myint)
myfloat = 7.0
print(myfloat)
myfloat = float(7)
print(myfloat)

#type casting
myfloat = int(7)
print("myfloat is now int", myfloat)
# Out:
# 7
# 7.0
# 7.0
# myfloat is now int 7

# %%
a,b = 3,4
print(a,b)
one = 1
two = 2
print(one + two)
# Out:
# 3 4
# 3

# %%
a = 1.2
b = True
c = False
d = 10
e = None
print(type(a), type(b), type(c), type(d), type(e))
# Out:
# <class 'float'> <class 'bool'> <class 'bool'> <class 'int'> <class 'NoneType'>

# %%
import numpy as np
#prints a random number between 1-7
np.random.randint(1,7)
# Out:
# 1

# %%
#prints a random number between 1-7 for 10 and 100 iterations
few_rolls = np.random.randint(1,7,size=10)
many_rolls = np.random.randint(1,7,size=100)
print(few_rolls)
print(many_rolls)
# Out:
# [5 1 2 6 5 6 6 4 1 3]
# [4 5 3 3 3 1 1 3 6 4 6 2 3 6 6 3 3 2 3 1 6 3 5 5 6 5 1 6 5 5 4 4 4 4 4 6 3
#  6 4 6 3 3 4 2 3 3 4 1 3 1 3 2 6 3 5 5 1 2 5 1 1 6 2 3 6 5 6 5 1 6 5 2 6 2
#  6 5 4 1 4 1 6 6 1 2 3 3 5 4 6 2 1 2 1 2 5 3 2 1 3 4]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#plotting histogram plots

#plot the distriution of few_rolls(10 sets of random numbers between 1-7)
few_counts = np.histogram(few_rolls, bins=np.arrange(0.5, 7.5))[0] #[0] onyl reports 

#plot the distriution of few_rolls(100 sets of random numbers between 1-7)
many_counts= np.histogram(many_rolls, bins=np.arrange(0.5, 7.5))[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       2 get_ipython().run_line_magic('matplotlib', 'inline')
#       4 #plotting histogram plots
#       5
#       6 #plot the distriution of few_rolls(10 sets of random numbers between 1-7)
# ----> 7 few_counts = np.histogram(few_rolls, bins=np.arrange(0.5, 7.5))[0] #[0] onyl reports
#       9 #plot the distriution of few_rolls(100 sets of random numbers between 1-7)
#      10 many_counts= np.histogram(many_rolls, bins=np.arrange(0.5, 7.5))[0]
#
# NameError: name 'np' is not defined
